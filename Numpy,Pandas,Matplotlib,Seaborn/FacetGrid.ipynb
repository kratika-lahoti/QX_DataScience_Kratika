# %%
a=sns.load_dataset("flights")
b=sns.PairGrid(a)
b.map(plt.scatter)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ad6b8bcc404c> in <module>
# ----> 1 a=sns.load_dataset("flights")
#       2 b=sns.PairGrid(a)
#       3 b.map(plt.scatter)
#
# NameError: name 'sns' is not defined

# %%
import seaborn as sns
a=sns.load_dataset("flights")
b=sns.PairGrid(a)
b.map(plt.scatter)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-125942d0076f> in <module>
#       2 a=sns.load_dataset("flights")
#       3 b=sns.PairGrid(a)
# ----> 4 b.map(plt.scatter)
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
a=sns.load_dataset("flights")
b=sns.PairGrid(a)
b.map(plt.scatter)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
a=sns.load_dataset("iris")
b=sns.FacetGrid(a,col="species")
b.map(plt.hist,"sepal_length")
