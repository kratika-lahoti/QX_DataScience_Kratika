# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
c=np.random.normal(loc=5,size=100,scale=2)
sns.distplot(c)

# %%
  import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
sns.set(style="white",color_codes=False)
a=sns.load_dataset("flights")
b=sns.PairGrid(a)
b.map(plt.scatter)

# %%
 import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
sns.set(style="white")
a=sns.load_dataset('tips')
sns.boxplot(x="day",y="total_bill",data=a)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
sns.set(style="white")
a=sns.load_dataset('tips')
sns.boxplot(x="day",y="total_bill",data=a)
sns.dispine(offset=10, trim=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-9acd2a590c03> in <module>
#       7 a=sns.load_dataset('tips')
#       8 sns.boxplot(x="day",y="total_bill",data=a)
# ----> 9 sns.dispine(offset=10, trim=True)
#
# AttributeError: module 'seaborn' has no attribute 'dispine'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
c=sns.color_palette()
sns.palplot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-210a070cfe3d> in <module>
#       5 from scipy import stats
#       6 c=sns.color_palette()
# ----> 7 sns.palplot()
#
# TypeError: palplot() missing 1 required positional argument: 'pal'

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
c=sns.color_palette()
sns.palplot(c)

# %%
c-sns.color_palette()
sns.palplot(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-517cf8fe262d> in <module>
# ----> 1 c-sns.color_palette()
#       2 sns.palplot(c)
#
# TypeError: unsupported operand type(s) for -: '_ColorPalette' and '_ColorPalette'
