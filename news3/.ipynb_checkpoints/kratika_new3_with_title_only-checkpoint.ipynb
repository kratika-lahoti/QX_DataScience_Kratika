# %%
import re
import pandas as pd
from nltk.corpus import stopwords

import copy
import numpy as np
import re
import nltk
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_selection import VarianceThreshold
from imblearn.over_sampling import SMOTE
from sklearn.dummy import DummyClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.metrics import accuracy_score
#from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
news = pd.read_excel("C:\\Users\\Kratika\\Downloads\\News333.xlsx")
news.head()
# Out:
#                                                Title  \
# 0  BS-VI transition may lead to dumping of old st...
# 1   Annual Report 2016-2017 of Bajaj Finserv Limited
# 2  Annual Report 2017-2018 of Eicher Motors Limit...
# 3  Hindalco Industries : Chairman Kumar Mangalam ...
# 4  WIPRO continues it's uptrend, although on a we...
#
#                                                 Body  \
# 0  BS-VI transition may lead to dumping of old st...
# 1  It is a broadly described annual report of Baj...
# 2  It is a broadly described annual report of\nEi...
# 3  (You can enter multiple email addresses separa...
# 4  WIPRO continues it's uptrend, although on a we...
#
#                                             Category MegaCategory
# 0  Annual Report - Comments made in the Annual Re...    Financial
# 1  Annual Report - Comments made in the Annual Re...    Financial
# 2  Annual Report - Comments made in the Annual Re...    Financial
# 3  Annual Report - Comments made in the Annual Re...    Financial
# 4  Annual Report - Comments made in the Annual Re...    Financial

# %%
from nltk.tokenize import word_tokenize 

def remove_stop_words(data):
    stop_words = set(stopwords.words('english'))
    stop_words.union(['january','february','march','april','may','june','july','august','september','october','november','december'])
    stop_words.union(['jan','feb','mar','apr','may','jun','jul','aug','sept','oct','nov','dec'])
    stop_words.union(['monday', 'tuesday', 'wednesday', 'thursday','friday','saturday','sunday'])
    stop_words.union(['am', 'pm'])
    word_tokens = word_tokenize(data) 
    filtered_sentence = []
    
    for w in word_tokens: 
        if w.lower() not in stop_words: 
            filtered_sentence.append(w) 
    
    return " ".join(filtered_sentence)

# %%
news['clean_title'] = news['Title'].apply(remove_stop_words) 

#remove_stop_words_Body

# %%
# ## Split data
print("\nSplitting data")

title_tr, title_te, MegaCategory_tr, MegaCategory_te = train_test_split(news['clean_title'], news.MegaCategory,test_size =.02)

title_tr, title_de, MegaCategory_tr , MegaCategory_de = train_test_split(title_tr,MegaCategory_tr,test_size =.02)

print("Training: ",len(title_tr))
print("Developement: ",len(title_de),)
print("Testing: ",len(title_te))
# Out:
# Splitting data
# Training:  2379
# Developement:  49
# Testing:  50

# %%
from sklearn.preprocessing import LabelEncoder

# # Data Preprocessing
# ## Vectorization of data
# Vectorize the data using Bag of words (BOW)
print("\nVectorizing data")
tokenizer = nltk.tokenize.RegexpTokenizer(r"\w+")
stop_words = nltk.corpus.stopwords.words("english")
vectorizer = CountVectorizer(tokenizer=tokenizer.tokenize, stop_words=stop_words)

vectorizer.fit(iter(title_tr))
Xtr = vectorizer.transform(iter(title_tr))
Xde = vectorizer.transform(iter(title_de))
Xte = vectorizer.transform(iter(title_te))

encoder = LabelEncoder()
encoder.fit(MegaCategory_tr)
Ytr = encoder.transform(MegaCategory_tr)
Yde = encoder.transform(MegaCategory_de)
Yte = encoder.transform(MegaCategory_te)
# Out:
# Vectorizing data

# %%
print(Ytr)
# Out:
# [ 4  4  6 ...  4 11  9]

# %%
Xtr
# Out:
# <2379x5377 sparse matrix of type '<class 'numpy.int64'>'
# 	with 20094 stored elements in Compressed Sparse Row format>

# %%
# # Train Models
# ### Baseline Model
# “stratified”: generates predictions by respecting the training set’s class distribution.
print("\n\nTraining baseline classifier")
dc = DummyClassifier(strategy="stratified")
dc.fit(Xtr, Ytr)
pred = dc.predict(Xde)
# Out:
# Training baseline classifier

# %%
print(classification_report(Yde, pred, labels=Ytr ,target_names=encoder.classes_))
print('Accuracy achieved is ' + str(np.mean(pred == Yde)))
# Out:
#                       precision    recall  f1-score   support
#
# Awards & Recognition       0.00      0.00      0.00        10
#    Corporate Updates       0.00      0.00      0.00        10
#                Event       0.00      0.00      0.00         0
#               Events       0.35      0.64      0.45        14
#            Financial       0.35      0.64      0.45        14
#               Growth       0.35      0.64      0.45        14
#        Industry News       0.00      0.00      0.00        10
#          Market Buzz       0.17      0.09      0.12        11
#        Negative News       0.40      0.20      0.27        10
#               People       0.35      0.64      0.45        14
#    Stock Performance       0.00      0.00      0.00         0
#   Uncategorised News       0.17      0.09      0.12        11
#
#            micro avg       0.32      0.43      0.37     23230
#            macro avg       0.22      0.31      0.24     23230
#         weighted avg       0.29      0.43      0.33     23230
#
# Accuracy achieved is 0.24489795918367346
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1870: UserWarning: labels size, 2379, does not match size of target_names, 12
#   .format(len(labels), len(target_names))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1439: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
# ### Decision Tree
print("Training Decision tree")
dt = DecisionTreeClassifier()
dt.fit(Xtr, Ytr)
pred = dt.predict(Xde)
print(classification_report(Yde, pred, labels=Ytr ,target_names=encoder.classes_))
print('Accuracy achieved is ' + str(np.mean(pred == Yde)))
# Out:
# Training Decision tree
#                       precision    recall  f1-score   support
#
# Awards & Recognition       0.75      0.30      0.43        10
#    Corporate Updates       0.75      0.30      0.43        10
#                Event       0.00      0.00      0.00         0
#               Events       0.47      0.57      0.52        14
#            Financial       0.47      0.57      0.52        14
#               Growth       0.47      0.57      0.52        14
#        Industry News       0.75      0.30      0.43        10
#          Market Buzz       0.70      0.64      0.67        11
#        Negative News       0.57      0.80      0.67        10
#               People       0.47      0.57      0.52        14
#    Stock Performance       0.00      0.00      0.00         0
#   Uncategorised News       0.70      0.64      0.67        11
#
#            micro avg       0.52      0.58      0.55     23230
#            macro avg       0.46      0.48      0.45     23230
#         weighted avg       0.54      0.58      0.55     23230
#
# Accuracy achieved is 0.5510204081632653
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1870: UserWarning: labels size, 2379, does not match size of target_names, 12
#   .format(len(labels), len(target_names))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1439: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
# ### Random Forest
print("Training Random Forest")
rf = RandomForestClassifier(n_estimators=40)
rf.fit(Xtr, Ytr)
pred = rf.predict(Xde)
print(classification_report(Yde, pred, labels=Ytr ,target_names=encoder.classes_))
print('Accuracy achieved is ' + str(np.mean(pred == Yde)))
# Out:
# Training Random Forest
#                       precision    recall  f1-score   support
#
# Awards & Recognition       0.83      0.50      0.62        10
#    Corporate Updates       0.83      0.50      0.62        10
#                Event       0.00      0.00      0.00         0
#               Events       0.42      0.79      0.55        14
#            Financial       0.42      0.79      0.55        14
#               Growth       0.42      0.79      0.55        14
#        Industry News       0.83      0.50      0.62        10
#          Market Buzz       0.67      0.36      0.47        11
#        Negative News       0.78      0.70      0.74        10
#               People       0.42      0.79      0.55        14
#    Stock Performance       0.00      0.00      0.00         0
#   Uncategorised News       0.67      0.36      0.47        11
#
#            micro avg       0.49      0.68      0.57     23230
#            macro avg       0.47      0.54      0.47     23230
#         weighted avg       0.55      0.68      0.57     23230
#
# Accuracy achieved is 0.5714285714285714
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1870: UserWarning: labels size, 2379, does not match size of target_names, 12
#   .format(len(labels), len(target_names))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1439: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
# ### Multinomial Naive Bayesian
print("Training Multinomial Naive Bayesian")
nb = MultinomialNB()
nb.fit(Xtr, Ytr)
pred_nb = nb.predict(Xde)
print(classification_report(Yde, pred_nb, labels=Ytr ,target_names=encoder.classes_))
print('Accuracy achieved is ' + str(np.mean(pred == Yde)))
# Out:
# Training Multinomial Naive Bayesian
#                       precision    recall  f1-score   support
#
# Awards & Recognition       0.80      0.40      0.53        10
#    Corporate Updates       0.80      0.40      0.53        10
#                Event       0.00      0.00      0.00         0
#               Events       0.48      0.71      0.57        14
#            Financial       0.48      0.71      0.57        14
#               Growth       0.48      0.71      0.57        14
#        Industry News       0.80      0.40      0.53        10
#          Market Buzz       0.86      0.55      0.67        11
#        Negative News       0.67      1.00      0.80        10
#               People       0.48      0.71      0.57        14
#    Stock Performance       0.00      0.00      0.00         0
#   Uncategorised News       0.86      0.55      0.67        11
#
#            micro avg       0.55      0.70      0.62     23230
#            macro avg       0.51      0.56      0.51     23230
#         weighted avg       0.59      0.70      0.61     23230
#
# Accuracy achieved is 0.5714285714285714
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1870: UserWarning: labels size, 2379, does not match size of target_names, 12
#   .format(len(labels), len(target_names))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1439: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
# ### Support Vector Classification
print("Training Support Vector Classification")
from sklearn.svm import SVC
svc = SVC()
svc.fit(Xtr, Ytr)
pred = svc.predict(Xde)
print(classification_report(Yde, pred, labels=Ytr ,target_names=encoder.classes_))
print('Accuracy achieved is ' + str(np.mean(pred == Yde)))
# Out:
# Training Support Vector Classification
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
#                       precision    recall  f1-score   support
#
# Awards & Recognition       0.00      0.00      0.00        10
#    Corporate Updates       0.00      0.00      0.00        10
#                Event       0.00      0.00      0.00         0
#               Events       0.29      1.00      0.44        14
#            Financial       0.29      1.00      0.44        14
#               Growth       0.29      1.00      0.44        14
#        Industry News       0.00      0.00      0.00        10
#          Market Buzz       0.00      0.00      0.00        11
#        Negative News       0.00      0.00      0.00        10
#               People       0.29      1.00      0.44        14
#    Stock Performance       0.00      0.00      0.00         0
#   Uncategorised News       0.00      0.00      0.00        11
#
#            micro avg       0.29      0.60      0.39     23230
#            macro avg       0.12      0.42      0.19     23230
#         weighted avg       0.17      0.60      0.27     23230
#
# Accuracy achieved is 0.2857142857142857
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1870: UserWarning: labels size, 2379, does not match size of target_names, 12
#   .format(len(labels), len(target_names))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1439: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
# ### Multilayered Perceptron
print("Training Multilayered Perceptron")
mlp = MLPClassifier(solver='adam', alpha=1e-5, hidden_layer_sizes=(100, 20), random_state=1, max_iter=400)
mlp.fit(Xtr, Ytr)
pred = mlp.predict(Xde)
print(classification_report(Yde, pred, labels=Ytr ,target_names=encoder.classes_))
print('Accuracy achieved is ' + str(np.mean(pred == Yde)))
# Out:
# Training Multilayered Perceptron
#                       precision    recall  f1-score   support
#
# Awards & Recognition       0.62      0.50      0.56        10
#    Corporate Updates       0.62      0.50      0.56        10
#                Event       0.00      0.00      0.00         0
#               Events       0.55      0.79      0.65        14
#            Financial       0.55      0.79      0.65        14
#               Growth       0.55      0.79      0.65        14
#        Industry News       0.62      0.50      0.56        10
#          Market Buzz       0.62      0.45      0.53        11
#        Negative News       0.88      0.70      0.78        10
#               People       0.55      0.79      0.65        14
#    Stock Performance       0.00      0.00      0.00         0
#   Uncategorised News       0.62      0.45      0.53        11
#
#            micro avg       0.59      0.70      0.64     23230
#            macro avg       0.58      0.60      0.57     23230
#         weighted avg       0.63      0.70      0.64     23230
#
# Accuracy achieved is 0.6122448979591837
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1870: UserWarning: labels size, 2379, does not match size of target_names, 12
#   .format(len(labels), len(target_names))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1439: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
# # Final Model: Multinomial Naive Bayesian
# **Multinomial Naive Bayesian** works the best. Lets run NB on our test data and get the confusion matrix and its heat map.
# ## Predict test data
print("\n\nPredicting test data using Multinomial Naive Bayesian")
pred_final = nb.predict(Xte)
print(classification_report(Yte, pred_final, labels=Ytr ,target_names=encoder.classes_))
print('Accuracy achieved is ' + str(accuracy_score(Yte,pred_final)))
# Out:
# Predicting test data using Multinomial Naive Bayesian
#                       precision    recall  f1-score   support
#
# Awards & Recognition       0.75      0.60      0.67         5
#    Corporate Updates       0.75      0.60      0.67         5
#                Event       0.00      0.00      0.00         1
#               Events       0.74      0.74      0.74        19
#            Financial       0.74      0.74      0.74        19
#               Growth       0.74      0.74      0.74        19
#        Industry News       0.75      0.60      0.67         5
#          Market Buzz       1.00      0.50      0.67         6
#        Negative News       0.47      1.00      0.64         8
#               People       0.74      0.74      0.74        19
#    Stock Performance       0.00      0.00      0.00         0
#   Uncategorised News       1.00      0.50      0.67         6
#
#            micro avg       0.69      0.73      0.71     26404
#            macro avg       0.69      0.67      0.65     26404
#         weighted avg       0.73      0.73      0.71     26404
#
# Accuracy achieved is 0.68

# %%
output = {"title":vectorizer.inverse_transform(Xte), "predicted":encoder.inverse_transform(pred_final),"actual": encoder.inverse_transform(Yte)}

# %%
df = pd.DataFrame(output, columns=["title","predicted","actual"])
df
# Out:
#                                                 title           predicted  \
# 0                                    [news, olympics]  Uncategorised News
# 1   [10, downgrade, fall, finance, housing, indiab...   Stock Performance
# 2   [bank, based, calling, mobile, number, rs, woman]  Uncategorised News
# 3   [bharat, forge, grid, hindalco, lupin, ntpc, p...  Uncategorised News
# 4                     [impact, industry, lead, titan]  Uncategorised News
# 5   [000, 20, business, capex, cr, jumps, news, nt...   Stock Performance
# 6   [000, 1, 2, 5, 50, better, deposit, fixed, giv...   Stock Performance
# 7     [answers, companies, online, papers, placement]              People
# 8   [bajaj, best, discounts, finserv, get, mobiles...  Uncategorised News
# 9   [bags, bank, contract, digital, icici, service...  Uncategorised News
# 10  [4, axis, bank, crore, fy19, growth, loan, low...   Stock Performance
# 11                           [2017, larsen, presents]  Uncategorised News
# 12     [165, case, crore, grid, gst, pays, power, rs]   Stock Performance
# 13  [bank, cuts, deposit, effect, india, mclr, rat...  Uncategorised News
# 14                        [2019, children, golf, itc]  Uncategorised News
# 15  [3, 5, 52, britannia, declines, demand, hits, ...   Stock Performance
# 16  [400, jobs, operations, shut, stake, steel, ta...       Negative News
# 17                [apply, online, po, posts, various]  Uncategorised News
# 18  [4, 6, bank, indusind, net, profit, q2, result...   Stock Performance
# 19          [270, bags, coal, cr, deal, india, techm]              Growth
# 20  [buy, future, grasim, hdfc, june, securities, ...   Stock Performance
# 21                   [gail, joins, podcast, pr, week]  Uncategorised News
# 22     [bags, l, mp, ntpc, order, plant, set, system]              Growth
# 23  [announces, bharti, indus, infratel, merger, t...           Financial
# 24            [bharti, competition, infratel, towers]           Financial
# 25                             [11, bank, trade, yes]   Stock Performance
# 26                                           [grasim]   Stock Performance
# 27  [blockchain, finance, giant, indian, launch, m...  Uncategorised News
# 28  [axis, bank, bring, card, credit, flipkart, ne...  Uncategorised News
# 29  [asian, digit, double, growth, net, paints, pr...   Stock Performance
# 30              [2019, admit, card, cards, ntpc, rrb]  Uncategorised News
# 31  [bharti, financial, indus, infratel, merger, n...           Financial
# 32                                        [itc, send]  Uncategorised News
# 33  [2019, apply, cadre, officers, recruitment, sb...              People
# 34                         [infra, pharma, sun, tech]   Stock Performance
# 35                   [broker, buy, call, coal, india]           Financial
# 36   [apply, diploma, engineer, grid, job, jr, power]              People
# 37  [hydro, power, processing, provide, site, stee...  Uncategorised News
# 38  [associate, jobs, mahindra, support, tech, tec...  Uncategorised News
# 39  [6, britannia, fmcg, higher, jumps, market, pr...   Stock Performance
# 40  [1, 2, 45, bank, consolidated, crore, icici, n...   Stock Performance
# 41  [bsl, crore, june, net, profit, qtr, reports, ...   Stock Performance
# 42                    [affected, global, pharma, sun]       Negative News
# 43                 [holdings, sbi, shareholders, xrp]   Stock Performance
# 44              [case, delhi, favour, hc, hul, rules]  Uncategorised News
# 45  [10, 77, earnings, jump, kicks, net, q1, seaso...   Stock Performance
# 46           [britannia, fire, house, injured, woman]       Negative News
# 47  [capacity, cement, expand, hard, heat, invests...              Growth
# 48  [announces, closure, factory, shares, steel, t...       Negative News
# 49                                    [great, letter]  Uncategorised News
#
#                 actual
# 0   Uncategorised News
# 1            Financial
# 2   Uncategorised News
# 3          Market Buzz
# 4   Uncategorised News
# 5               Growth
# 6   Uncategorised News
# 7   Uncategorised News
# 8   Uncategorised News
# 9               Growth
# 10   Stock Performance
# 11  Uncategorised News
# 12       Negative News
# 13  Uncategorised News
# 14  Uncategorised News
# 15   Stock Performance
# 16       Negative News
# 17  Uncategorised News
# 18   Stock Performance
# 19              Growth
# 20         Market Buzz
# 21  Uncategorised News
# 22              Growth
# 23           Financial
# 24  Uncategorised News
# 25   Stock Performance
# 26  Uncategorised News
# 27              Growth
# 28  Uncategorised News
# 29   Stock Performance
# 30  Uncategorised News
# 31           Financial
# 32  Uncategorised News
# 33              People
# 34  Uncategorised News
# 35           Financial
# 36              People
# 37  Uncategorised News
# 38              People
# 39       Industry News
# 40   Stock Performance
# 41           Financial
# 42       Negative News
# 43   Stock Performance
# 44       Negative News
# 45   Stock Performance
# 46       Negative News
# 47              Growth
# 48       Negative News
# 49  Uncategorised News
